# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/NYT/NYT_Dataset.csv'

# %%
import gensim

# %%
articles = pd.read_csv(file_path)
articles = articles[['title','topic','abstract','keywords']]
articles = articles.sample(n=50000, random_state=26).reset_index()

# %%
display(articles)
# Out:
#         index                                              title     topic  \
# 0       36036        Inquiry on C.I.A. Detentions to Be Unveiled   Foreign
# 1       61202  Tony Abbott, Ousted Australian Leader, Urges E...   Foreign
# 2      101496  U.K. Says It Can’t Guarantee Assistance for Ci...   Foreign
# 3       77121  Sumiteru Taniguchi, 88, Who Survived Nagasaki ...   Foreign
# 4       51808  Agreement in Northern Ireland Averts Collapse ...   Foreign
# ...       ...                                                ...       ...
# 49995   65418  New Ad Promotes John Kasich, and It Makes Him ...  Politics
# 49996   88107  Store’s Bid to Shame Customers Over Plastic Ba...   Foreign
# 49997   32665  A Melting Greenland Weighs Perils Against Pote...   Foreign
# 49998   18681      Remembering Rabin, Some See His Legacy Fading   Foreign
# 49999   82123  Ex-Catalonia Leader Can Be Extradited, but Not...   Foreign
#
#                                                 abstract  \
# 0      A United Nations investigator, whose report on...
# 1      In a speech in London, Mr. Abbott offered Aust...
# 2      Britain’s stance on the case of Nazanin Zaghar...
# 3      Painfully wounded in the atomic bombing when h...
# 4      The deal addressed an austerity budget dispute...
# ...                                                  ...
# 49995  The ad, from a “super PAC” backing Mr. Kasich,...
# 49996  A Vancouver store introduced plastic bags with...
# 49997  As warming temperatures are upending tradition...
# 49998  Fifteen years after his assassination, Prime M...
# 49999  A German court ruled that Carles Puigdemont co...
#
#                                                 keywords
# 0      ['United Nations', 'Central Intelligence Agenc...
# 1      ['Abbott, Tony', 'Immigration and Emigration',...
# 2      ['Zaghari-Ratcliffe, Nazanin', 'Iran', 'Great ...
# 3      ['Taniguchi, Sumiteru (1929-2017)', 'Deaths (O...
# 4      ['Northern Ireland', 'Dalby, Douglas', 'Great ...
# ...                                                  ...
# 49995  ['Political Advertising', 'Presidential Electi...
# 49996  ['Plastic Bags', 'Supermarkets and Grocery Sto...
# 49997  ['Metals and Minerals', 'Global Warming', 'Fis...
# 49998  ['Rabin, Yitzhak', 'Assassinations and Attempt...
# 49999  ['Politics and Government', 'Secession and Ind...
#
# [50000 rows x 5 columns]

# %%
from gensim.models import KeyedVectors

# Path to your Word2Vec binary file on Google Drive
path_to_word2vec = '/content/drive/My Drive/NYT/GoogleNews-vectors-negative300.bin.gz'

from gensim.models import KeyedVectors

# Load the Word2Vec model directly from the compressed .gz file
word2vec_model = KeyedVectors.load_word2vec_format(path_to_word2vec, binary=True)

# %%
import re
# get NLTK libraries
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

def clean_text(text, remove_stopwords = False):
    # Simple text break
    # data cleaning

    text = re.sub("(\\t)", ' ', str(text)).lower() #remove escape charecters
    text = re.sub("(\\r)", ' ', str(text)).lower()
    text = re.sub("(\\n)", ' ', str(text)).lower()

    text = re.sub("(__+)", ' ', str(text)).lower()   #remove _ if it occors more than one time consecutively
    text = re.sub("(--+)", ' ', str(text)).lower()   #remove - if it occors more than one time consecutively
    text = re.sub("(~~+)", ' ', str(text)).lower()   #remove ~ if it occors more than one time consecutively
    text = re.sub("(\+\++)", ' ', str(text)).lower()   #remove + if it occors more than one time consecutively
    text = re.sub("(\.\.+)", ' ', str(text)).lower()   #remove . if it occors more than one time consecutively

    text = re.sub(r"[<>()|&©ø\[\]\'\",;?~*!]", ' ', str(text)).lower() #remove <>()|&©ø"',;?~*!

    text = re.sub("(mailto:)", ' ', str(text)).lower() #remove mailto:
    text = re.sub(r"(\\x9\d)", ' ', str(text)).lower() #remove \x9* in text
    text = re.sub("([iI][nN][cC]\d+)", 'INC_NUM', str(text)).lower() #replace INC nums to INC_NUM
    text = re.sub("([cC][mM]\d+)|([cC][hH][gG]\d+)", 'CM_NUM', str(text)).lower() #replace CM# and CHG# to CM_NUM


    text = re.sub("(\.\s+)", ' ', str(text)).lower() #remove full stop at end of words(not between)
    text = re.sub("(\-\s+)", ' ', str(text)).lower() #remove - at end of words(not between)
    text = re.sub("(\:\s+)", ' ', str(text)).lower() #remove : at end of words(not between)

    text = re.sub("(\s+.\s+)", ' ', str(text)).lower() #remove any single charecters hanging between 2 spaces
    text = re.sub("(\s+)",' ',str(text)).lower() #remove multiple spaces

    #Sho uld always be last
    text = re.sub("(\s+.\s+)", ' ', str(text)).lower() #remove any single charecters hanging between 2 spaces

    # tokenization
    text = text.lower()
#     text = nltk.word_tokenize(text) # converts review to tokens
    return text

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
articles['Cleaned_abstract'] = articles['abstract'].progress_apply(clean_text)
articles['Cleaned_title'] = articles['title'].progress_apply(clean_text)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
#   0%|          | 0/50000 [00:00<?, ?it/s]

# %%
display(articles['Cleaned_abstract'])
# Out:
# 0        a united nations investigator whose report on ...
# 1        in speech in london mr abbott offered australi...
# 2        britain’s stance on the case of nazanin zaghar...
# 3        painfully wounded in the atomic bombing when h...
# 4        the deal addressed an austerity budget dispute...
#                                ...
# 49995    the ad from “super pac” backing mr kasich show...
# 49996    a vancouver store introduced plastic bags with...
# 49997    as warming temperatures are upending tradition...
# 49998    fifteen years after his assassination prime mi...
# 49999    a german court ruled that carles puigdemont co...
# Name: Cleaned_abstract, Length: 50000, dtype: object

# %%
display(articles['Cleaned_title'])
# Out:
# 0               inquiry on c.i.a detentions to be unveiled
# 1        tony abbott ousted australian leader urges eur...
# 2        u.k says it can’t guarantee assistance for cit...
# 3        sumiteru taniguchi 88 who survived nagasaki to...
# 4        agreement in northern ireland averts collapse ...
#                                ...
# 49995    new ad promotes john kasich and it makes him u...
# 49996    store’s bid to shame customers over plastic ba...
# 49997    a melting greenland weighs perils against pote...
# 49998         remembering rabin some see his legacy fading
# 49999    ex-catalonia leader can be extradited but not ...
# Name: Cleaned_title, Length: 50000, dtype: object

# %%
from time import time
import spacy
nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser']) # disabling Named Entity Recognition for speed

#Taking advantage of spaCy .pipe() method to speed-up the cleaning process:
#If data loss seems to be happening(i.e len(text) = 50 instead of 75 etc etc) in this cell , decrease the batch_size parametre

t = time()

#Batch the data points into 5000 and run on all cores for faster preprocessing
abstracts = [str(doc) for doc in nlp.pipe(articles['Cleaned_abstract'], batch_size=5000)]

#Takes 7-8 mins
print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 1.73 mins

# %%
abstracts[0]
# Out:
# 'a united nations investigator whose report on the c.i.a.’s use of secret detentions and interrogation techniques is to be released called on the united states to publicly account for the policy.'

# %%
t = time()

#Batch the data points into 5000 and run on all cores for faster preprocessing
title = ['_START_ '+ str(doc) + ' _END_' for doc in nlp.pipe(articles['Cleaned_title'], batch_size=5000)]

#Takes 7-8 mins
print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 0.61 mins

# %%
title[0]
# Out:
# '_START_ inquiry on c.i.a detentions to be unveiled _END_'

# %%
articles['Cleaned_abstract'] = pd.Series(abstracts)
articles['Cleaned_title'] = pd.Series(title)

# %%
import matplotlib.pyplot as plt

abstract_count = []
title_count = []

for sent in articles['Cleaned_abstract']:
    abstract_count.append(len(sent.split()))
for sent in articles['Cleaned_title']:
    title_count.append(len(sent.split()))

graph_df = pd.DataFrame()
graph_df['text'] = abstract_count
graph_df['summary'] = title_count


graph_df.hist(bins = 10)
plt.show()

# %%
articles['Clean_length'] = articles['Cleaned_abstract'].progress_apply(lambda x: len(x.split()))
min_len = np.min(articles['Clean_length'])
max_len = np.max(articles['Clean_length'])
avg_len = np.mean(articles['Clean_length'])
std_len = np.sqrt(np.var(articles['Clean_length']))
med_len = np.median(articles['Clean_length'])

print("Shortest Abstract", min_len)
print("Longest Abstract", max_len)
print("Median Abstract", med_len)
print("Average Abstract", avg_len)
print("Standard deviation", std_len)
print(f"Percent articles under average or {avg_len} words:", articles[articles['Clean_length'] <= (avg_len)]['Clean_length'].count()/len(articles['Clean_length']))
print(f"Percent articles under 0.5 stds or {avg_len + 0.5*std_len} words:", articles[articles['Clean_length'] <= (avg_len + 0.5*std_len)]['Clean_length'].count()/len(articles['Clean_length']))
print(f"Percent articles under 1 std or {avg_len + std_len} words:", articles[articles['Clean_length'] <= (avg_len + std_len)]['Clean_length'].count()/len(articles['Clean_length']))
print(f"Percent articles under 2 stds or {avg_len + 2*std_len} words:", articles[articles['Clean_length'] <= (avg_len + 2*std_len)]['Clean_length'].count()/len(articles['Clean_length']))
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# Shortest Abstract 1
# Longest Abstract 155
# Median Abstract 23.0
# Average Abstract 23.41556
# Standard deviation 7.121937228479341
# Percent articles under average or 23.41556 words: 0.5069
# Percent articles under 0.5 stds or 26.97652861423967 words: 0.7293
# Percent articles under 1 std or 30.53749722847934 words: 0.90486
# Percent articles under 2 stds or 37.65943445695868 words: 0.97734

# %%
articles['Clean_title_length'] = articles['Cleaned_title'].progress_apply(lambda x: len(x.split()))
min_len = np.min(articles['Clean_title_length'])
max_len = np.max(articles['Clean_title_length'])
avg_len = np.mean(articles['Clean_title_length'])
std_len = np.sqrt(np.var(articles['Clean_title_length']))
med_len = np.median(articles['Clean_title_length'])

print("Shortest title", min_len)
print("Longest title", max_len)
print("Median title", med_len)
print("Average title", avg_len)
print("Standard deviation", std_len)
print(f"Percent titles under average or {avg_len} words:", articles[articles['Clean_title_length'] <= (avg_len)]['Clean_title_length'].count()/len(articles['Clean_title_length']))
print(f"Percent titles under 0.5 stds or {avg_len + 0.5*std_len} words:", articles[articles['Clean_title_length'] <= (avg_len + 0.5*std_len)]['Clean_title_length'].count()/len(articles['Clean_title_length']))
print(f"Percent titles under 1 std or {avg_len + std_len} words:", articles[articles['Clean_title_length'] <= (avg_len + std_len)]['Clean_title_length'].count()/len(articles['Clean_title_length']))
print(f"Percent titles under 2 stds or {avg_len + 2*std_len} words:", articles[articles['Clean_title_length'] <= (avg_len + 2*std_len)]['Clean_title_length'].count()/len(articles['Clean_title_length']))
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# Shortest title 3
# Longest title 27
# Median title 10.0
# Average title 10.48706
# Standard deviation 2.4982939291444475
# Percent titles under average or 10.48706 words: 0.51114
# Percent titles under 0.5 stds or 11.736206964572224 words: 0.6609
# Percent titles under 1 std or 12.985353929144447 words: 0.7928
# Percent titles under 2 stds or 15.483647858288894 words: 0.97798

# %%
max_abstract_length = 35
max_title_length = 15

# %%
#Select the Summaries and Text between max len defined above

cleaned_abstracts = np.array(articles['Cleaned_abstract'])
cleaned_titles = np.array(articles['Cleaned_title'])

shortened_abstract=[]
shortened_titles=[]

for i in range(len(cleaned_abstracts)):
    if(len(cleaned_abstracts[i].split())<=max_abstract_length and len(cleaned_titles[i].split())<=max_title_length):
        shortened_abstract.append(cleaned_abstracts[i])
        shortened_titles.append(cleaned_titles[i])

processed_articles=pd.DataFrame({'Abstract':shortened_abstract,'Title':shortened_titles})
display(processed_articles.head(2))
processed_articles['Title'] = processed_articles['Title'].progress_apply(lambda x : 'sostok '+ x + ' eostok')
display(processed_articles.head(2))
# Out:
#                                             Abstract  \
# 0  a united nations investigator whose report on ...
# 1  in speech in london mr abbott offered australi...
#
#                                                Title
# 0  _START_ inquiry on c.i.a detentions to be unve...
# 1  _START_ tony abbott ousted australian leader u...
#   0%|          | 0/47560 [00:00<?, ?it/s]
#                                             Abstract  \
# 0  a united nations investigator whose report on ...
# 1  in speech in london mr abbott offered australi...
#
#                                                Title
# 0  sostok _START_ inquiry on c.i.a detentions to ...
# 1  sostok _START_ tony abbott ousted australian l...

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(processed_articles['Abstract']),np.array(processed_articles['Title']),test_size=0.1,random_state=26,shuffle=True)

# %%
#Lets tokenize the text to get the vocab count , you can use Spacy here also
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))

# %%
import numpy as np

embedding_dim = 300  # Google News vectors are of this dimension
vocab_size = len(x_tokenizer.word_index) + 1  # Plus one for the padding token

embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in x_tokenizer.word_index.items():
    try:
        embedding_vector = word2vec_model[word]
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
    except KeyError:
        continue  # Words not found in the embedding index will be all zeros.

# %%
thresh=2

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value

print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 43.72900625290683
# Total Coverage of rare words: 1.71964257771618

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt)
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences (i.e one-hot encodeing all the words)
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr)
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_abstract_length, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_abstract_length, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

print("Size of vocabulary in X = {}".format(x_voc))
# Out:
# Size of vocabulary in X = 21779

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

# %%
thresh=2

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value

print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 45.13196009011908
# Total Coverage of rare words: 2.091002797820645

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt)
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences (i.e one hot encode the text in Y)
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr)
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val)

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_title_length, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_title_length, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1
print("Size of vocabulary in Y = {}".format(y_voc))
# Out:
# Size of vocabulary in Y = 13639

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

# %%
ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
from keras import backend as K
import gensim
from numpy import *
import numpy as np
import pandas as pd
import re
from bs4 import BeautifulSoup
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")

print("Size of vocabulary from the w2v model = {}".format(x_voc))

K.clear_session()

latent_dim = 300
embedding_dim=200

# Encoder
encoder_inputs = Input(shape=(max_abstract_length,))

#embedding layer
enc_emb = Embedding(input_dim=38703, output_dim=300, weights=[embedding_matrix], trainable=False)(encoder_inputs)



#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# Size of vocabulary from the w2v model = 21779
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 35)]                 0         []
#
#  embedding (Embedding)       (None, 35, 300)              1161090   ['input_1[0][0]']
#                                                           0
#
#  lstm (LSTM)                 [(None, 35, 300),            721200    ['embedding[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  lstm_1 (LSTM)               [(None, 35, 300),            721200    ['lstm[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  embedding_1 (Embedding)     (None, None, 200)            2727800   ['input_2[0][0]']
#
#  lstm_2 (LSTM)               [(None, 35, 300),            721200    ['lstm_1[0][0]']
#                               (None, 300),
#                               (None, 300)]
#
#  lstm_3 (LSTM)               [(None, None, 300),          601200    ['embedding_1[0][0]',
#                               (None, 300),                           'lstm_2[0][1]',
#                               (None, 300)]                           'lstm_2[0][2]']
#
#  time_distributed (TimeDist  (None, None, 13639)          4105339   ['lstm_3[0][0]']
#  ributed)
#
# ==================================================================================================
# Total params: 21208839 (80.91 MB)
# Trainable params: 9597939 (36.61 MB)
# Non-trainable params: 11610900 (44.29 MB)
# __________________________________________________________________________________________________

# %%
# Get the size of tokenizer vocabulary
x_voc_size = len(x_tokenizer.word_index) + 1  # +1 for zero padding
print(f"Tokenizer Vocabulary Size: {x_voc_size}")
# Out:
# Tokenizer Vocabulary Size: 38703

# %%
# Check embedding matrix size
print(f"Embedding Matrix Shape: {embedding_matrix.shape}")
# Out:
# Embedding Matrix Shape: (38703, 300)

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/50
# 335/335 [==============================] - 175s 470ms/step - loss: 5.1015 - val_loss: 4.4960
# Epoch 2/50
# 335/335 [==============================] - 151s 451ms/step - loss: 4.5349 - val_loss: 4.3823
# Epoch 3/50
# 335/335 [==============================] - 152s 453ms/step - loss: 4.4137 - val_loss: 4.2699
# Epoch 4/50
# 335/335 [==============================] - 150s 446ms/step - loss: 4.3170 - val_loss: 4.2042
# Epoch 5/50
# 335/335 [==============================] - 150s 447ms/step - loss: 4.2455 - val_loss: 4.1481
# Epoch 6/50
# 335/335 [==============================] - 150s 447ms/step - loss: 4.1849 - val_loss: 4.1051
# Epoch 7/50
# 335/335 [==============================] - 150s 449ms/step - loss: 4.1388 - val_loss: 4.0670
# Epoch 8/50
# 335/335 [==============================] - 150s 449ms/step - loss: 4.0994 - val_loss: 4.0434
# Epoch 9/50
# 335/335 [==============================] - 151s 451ms/step - loss: 4.0630 - val_loss: 4.0133
# Epoch 10/50
# 335/335 [==============================] - 151s 452ms/step - loss: 4.0227 - val_loss: 3.9713
# Epoch 11/50
# 335/335 [==============================] - 149s 445ms/step - loss: 3.9758 - val_loss: 3.9354
# Epoch 12/50
# 335/335 [==============================] - 149s 446ms/step - loss: 3.9342 - val_loss: 3.9097
# Epoch 13/50
# 335/335 [==============================] - 151s 450ms/step - loss: 3.8901 - val_loss: 3.8783
# Epoch 14/50
# 335/335 [==============================] - 151s 451ms/step - loss: 3.8463 - val_loss: 3.8453
# Epoch 15/50
# 335/335 [==============================] - 152s 452ms/step - loss: 3.8056 - val_loss: 3.8091
# Epoch 16/50
# 335/335 [==============================] - 151s 449ms/step - loss: 3.7656 - val_loss: 3.7826
# Epoch 17/50
# 335/335 [==============================] - 160s 476ms/step - loss: 3.7276 - val_loss: 3.7648
# Epoch 18/50
# 335/335 [==============================] - 156s 466ms/step - loss: 3.6903 - val_loss: 3.7180
# Epoch 19/50
# 335/335 [==============================] - 150s 449ms/step - loss: 3.6550 - val_loss: 3.7116
# Epoch 20/50
# 335/335 [==============================] - 149s 445ms/step - loss: 3.6227 - val_loss: 3.6780
# Epoch 21/50
# 335/335 [==============================] - 149s 446ms/step - loss: 3.5961 - val_loss: 3.6643
# Epoch 22/50
# 335/335 [==============================] - 149s 445ms/step - loss: 3.5630 - val_loss: 3.6526
# Epoch 23/50
# 335/335 [==============================] - 151s 451ms/step - loss: 3.5353 - val_loss: 3.6336
# Epoch 24/50
# 335/335 [==============================] - 150s 449ms/step - loss: 3.5077 - val_loss: 3.6213
# Epoch 25/50
# 335/335 [==============================] - 151s 450ms/step - loss: 3.4816 - val_loss: 3.6110
# Epoch 26/50
# 335/335 [==============================] - 150s 447ms/step - loss: 3.4559 - val_loss: 3.6098
# Epoch 27/50
# 335/335 [==============================] - 153s 457ms/step - loss: 3.4310 - val_loss: 3.5766
# Epoch 28/50
# 335/335 [==============================] - 154s 460ms/step - loss: 3.4062 - val_loss: 3.5692
# Epoch 29/50
# 335/335 [==============================] - 151s 452ms/step - loss: 3.3821 - val_loss: 3.5531
# Epoch 30/50
# 335/335 [==============================] - 152s 454ms/step - loss: 3.3585 - val_loss: 3.5394
# Epoch 31/50
# 335/335 [==============================] - 151s 451ms/step - loss: 3.3353 - val_loss: 3.5243
# Epoch 32/50
# 335/335 [==============================] - 151s 451ms/step - loss: 3.3126 - val_loss: 3.5219
# Epoch 33/50
# 335/335 [==============================] - 150s 449ms/step - loss: 3.2903 - val_loss: 3.5138
# Epoch 34/50
# 335/335 [==============================] - 151s 452ms/step - loss: 3.2685 - val_loss: 3.5044
# Epoch 35/50
# 335/335 [==============================] - 151s 450ms/step - loss: 3.2462 - val_loss: 3.5068
# Epoch 36/50
# 335/335 [==============================] - 150s 448ms/step - loss: 3.2253 - val_loss: 3.4914
# Epoch 37/50
# 335/335 [==============================] - 151s 450ms/step - loss: 3.2041 - val_loss: 3.4709
# Epoch 38/50
# 335/335 [==============================] - 155s 462ms/step - loss: 3.1836 - val_loss: 3.4734
# Epoch 39/50
# 335/335 [==============================] - 153s 457ms/step - loss: 3.1643 - val_loss: 3.4711
# Epoch 39: early stopping

# %%
import pickle

# Save the history
with open('/content/drive/My Drive/NYT/model_history.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# Download the history file if you're on Google Colab
files.download('/content/drive/My Drive/NYT/model_history.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-ce3c52d6a2e6> in <cell line: 8>()
#       6
#       7 # Download the history file if you're on Google Colab
# ----> 8 files.download('/content/drive/My Drive/NYT/model_history.pkl')
#
# NameError: name 'files' is not defined

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_abstract_length,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_outputs2)

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]

        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_title_length-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2title(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2abstract(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Abstract:",seq2abstract(x_tr[i]))
    print("Original Title:",seq2title(y_tr[i]))
    print("Predicted Title:",decode_sequence(x_tr[i].reshape(1,max_abstract_length)))
    print("\n")
# Out:
# Abstract: swamped with homicides investigators cope with too little expertise and too much corruption and they are targets themselves
# Original Title: start in mexican drug war investigators are fearful end
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted Title:  start in mexico election
#
#
# Abstract: here are some likely contenders according to allies and advisers of the clintons and prominent democrats and look at their strengths and weaknesses
# Original Title: start who might hillary clinton running mate be if she the nominee end
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted Title:  start what you know about the 2020 democrats end
#
#
# Abstract: the trial of the iraqi journalist who threw his shoes at president george bush was adjourned until march 12 muntader al zaidi has been incarcerated since dec 14
# Original Title: start trial of iraqi ‘shoe thrower’ is end
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start ex president of war crimes in iraq end
#
#
# Abstract: the move raises concerns about academic freedom in macau where professors have little formal protection if they ideas that are unpopular with academic and political leaders
# Original Title: start macau scholar says he lost his job over pro democracy activism end
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted Title:  start in china and china is seen in the u s end
#
#
# Abstract: mr barrow well respected diplomat was chosen day after his predecessor ivan rogers announced his decision to quit
# Original Title: start britain names tim new top diplomat to e u end
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start former former president of the past end
#
#
# Abstract: just as the war effort grows unpopular at home german forces are fighting in the increasingly violent regions of northern afghanistan
# Original Title: start grim reality for german forces in kunduz end
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start in iraq war in iraq end
#
#
# Abstract: the basque nationalist political party already illegal in spain announced thursday that it would dissolve itself in france as well
# Original Title: start france basque party to disband end
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted Title:  start italy leader says he will seek to vote end
#
#
# Abstract: mr rezaian will have spent his day in captivity as of friday the same length of time as the americans held during the 1979 81 iran hostage crisis
# Original Title: start jason rezaian washington post reporter nears grim milestone in iran end
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted Title:  start a american who helped be dead at u s dies at end
#
#
# Abstract: f b i documents open window into the secretive process by which officials place the names of people suspected of links to terrorism on list ”
# Original Title: start documenting the process end
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# Predicted Title:  start u s says it will have been killed in iran end
#
#
# Abstract: israeli officials unveiled plaza where men and women can pray together but the move was denounced as discriminatory by the main group that has protested the rules at the holy site
# Original Title: start prayer plaza in jerusalem for both ignites uproar end
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# Predicted Title:  start israel and palestinians are said to have been killed by israel end
#
#
# Abstract: a large group of gunmen armed with rifles grenades and bombs killed at least 14 people in an audacious midday robbery according to officials and witness
# Original Title: gunmen rob baghdad jewelry stores in sight of checkpoints killing at least 14 end
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start iraq attack kills dozens in iraq end
#
#
# Abstract: speaking before an inquiry on wednesday the news corporation chief rupert murdoch sought to deflect suggestions that he wielded influence with british officials to further his corporate interests
# Original Title: start murdoch center stage plays powerless broker end
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start murdoch says he will resign end
#
#
# Abstract: the result was the first loss by kennedy in massachusetts election and demonstrated the progressive energy that is reshaping the democratic party
# Original Title: start ed markey held off joseph kennedy in democratic senate clash in massachusetts end
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start the new york primary end
#
#
# Abstract: president hu visit to xinjiang occurred as local officials dismissed reports that trials would begin this week of suspects in ethnic violence
# Original Title: start chinese president visits volatile xinjiang end
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start china says china will meet with china end
#
#
# Abstract: the criticism adds to backlash against findings by the johnson government that called britain “model for other white majority countries ”
# Original Title: u n panel is scathing in its criticism of british report on race end
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start britain says it will be in britain end
#
#
# Abstract: the proposed charter which gives the military powerful role won strong support in central thailand but was opposed in the northeast and far south
# Original Title: start thailand’s divisions on display in vote new constitution end
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start south sudan leader says it will meet with south sudan end
#
#
# Abstract: a protester was shot and the compound of former prime minister abhisit vejjajiva was damaged by small explosion during the unrest
# Original Title: start thousands march against thai leader in 3rd day of protests end
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start thai police kill dozens in istanbul end
#
#
# Abstract: senator lindsey graham of south carolina one of the most hawkish foreign policy voices in the race said he has concluded “this is not my time” despite making difference in the crowded republican presidential field
# Original Title: start lindsey graham halts his bid for the presidency end
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start bernie sanders says he will not not on the iowa end
#
#
# Abstract: the afghan interior ministry said the publications in english and were as mouthpieces and propaganda tools for the taliban ”
# Original Title: start pakistani papers banned by afghanistan in east end
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start taliban say u s is killed in afghanistan end
#
#
# Abstract: the arctic sea missing since last month was 300 miles off cape verde the russia defense ministry said
# Original Title: start russia says ship and crew are safe end
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start russia says it will be killed in ukraine end
#
#
# Abstract: footage released week after the tragedy showed how the dam released 2 5 billion gallons of brown sludge that buried people cars and buildings in seconds
# Original Title: start a deadly river of mud video of brazil dam collapse emerges end
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# Predicted Title:  start after fire in nepal end
#
#
# Abstract: with turnout the key to victory in florida some democrats have expressed concern about lack of enthusiasm from black and latino voters
# Original Title: with early voting underway in florida democrats worry about black and latino support end
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# Predicted Title:  start the candidates are the 2020 democrats are the end
#
#
# Abstract: activists and residents said security forces carried out military operations against those seeking to topple the assad government
# Original Title: start political cartoonist whose work skewered assad is beaten in syria end
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# Predicted Title:  start sudan forces are said to protest end
#
#
# Abstract: hours after her nomination threatened to upend the country’s politics the move was rebuked by the monarch as “inappropriate” behavior
# Original Title: start thailand’s king rejects his candidacy for prime minister end
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start a politician in japan is sworn in the election end
#
#
# Abstract: these three states have major races that will signal the intensity of republican support for president trump and the degree of democratic strength in the suburbs
# Original Title: start election day 2019 key votes in virginia kentucky mississippi end
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted Title:  start the democratic primary election end
#
#
# Abstract: in the deadliest attack in the capital since june bombers struck main street of mixed sunni and shiite neighborhood
# Original Title: start triple blasts kill 28 in northern baghdad end
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted Title:  start suicide bomber kills dozens in iraq end
#
#
# Abstract: police said the number of protesters many of whom are farmers from northeast thailand was down sharply to 20 000 people from more than 100 000 on sunday
# Original Title: start thailand protests continue but their scale end
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start hong kong police clash with police end
#
#
# Abstract: an interactive timeline of hillary rodham clinton’s life and career
# Original Title: start milestones hillary rodham clinton end
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start hillary clinton on the n s end
#
#
# Abstract: with large scale demonstrations showing little sign of winding down president aleksandr lukashenko’s security forces appear to have shifted from mass repression to more targeted disappearances
# Original Title: start belarus protest leader vanishes amid reports of masked abductors end
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start in myanmar war in myanmar end
#
#
# Abstract: for the second time in two days taliban fighters attacked provincial capital as government forces scrambled to respond amid peace talks
# Original Title: start taliban attack second afghan city in days as peace deal nears end
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start taliban attack on taliban attack in afghanistan end
#
#
# Abstract: trump’s throw everything at the wall strategy week before election day particularly constitutionally dubious call to end birthright citizenship has brought new headaches for republicans
# Original Title: start the trump effect hand and ads days to go end
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted Title:  start democrats say democrats are the 2020 democrats are the end
#
#
# Abstract: a blaze that killed seven at garment factory and the subsequent outrage exposed complicated and at times tense cohabitation of italian residents and chinese migrants
# Original Title: start deadly factory fire bares racial tensions in italy end
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start fire in china kills at least dead in china end
#
#
# Abstract: an official tally shows the deep cultural conservatism of the egyptian public
# Original Title: start islamists win 70 of seats in the egyptian parliament end
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted Title:  start a new york times in the end
#
#
# Abstract: rioting and looting spread to at least eight areas and broke out for the first time in another big city
# Original Title: start rioting widens in london on 3rd night of unrest end
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# Predicted Title:  start in clashes in congo city is killed in the streets end
#
#
# Abstract: an audit of and recommendations for the united states immigration and customs secure communities program
# Original Title: start report by the inspector general on secure communities end
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 40ms/step
# Predicted Title:  start report on the u s and the n s end
#
#
# Abstract: both the majority han chinese and minority uighurs in urumqi the regional capital of xinjiang say they will not let the bloodshed come between them
# Original Title: start in china’s far west city struggles to move on end
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start in china and china is seen in china end
#
#
# Abstract: as the french chef jérôme brochot returns his michelin star here is look at others who have turned down celebrated honors and awards
# Original Title: start just saying no who have shunned awards end
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start a royal royal prince is the end
#
#
# Abstract: an attack on helmand province police headquarters was part of the militants’ increased efforts to protect opium poppy farmers and their economic interests
# Original Title: start in poppy war taliban aim to protect cash crop end
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start afghan forces kill dozens in afghanistan end
#
#
# Abstract: israel is the only nation with gender neutral draft but that may sound more equal than it is as one woman who made it near the top learned
# Original Title: start the israeli general with an end
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted Title:  start israel and palestinians have been been in the west bank end
#
#
# Abstract: despite poor human rights record the u s still broadly engages with the country’s dictator teodoro obiang nguema mbasogo
# Original Title: start u s engages with an iron leader in equatorial guinea end
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start u s and cuba on human rights rights end
#
#
# Abstract: april 2011 japan began dumping radioactive water from the damaged fukushima daiichi nuclear plant into the pacific ocean to make room for more contaminated water ken reports
# Original Title: start timescast radioactive water released end
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start japan says it will be japanese ship in japan end
#
#
# Abstract: while many regard the partially plant matter as an elixir environmentalists say taking peat from centuries old vital ecosystems
# Original Title: start british soil is battlefield over for sake end
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted Title:  start in japan and japan is still in the arctic end
#
#
# Abstract: mr the disaster agency spokesman known for knocking down rumors with science had cancer while helping indonesia through “year of disasters ”
# Original Title: start indonesia disaster spokesman dies at 49 end
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted Title:  start a official says he was killed in south africa end
#
#
# Abstract: the official focus of the talks among the nato ministers was whether to push alliance membership for ukraine but broader question on russia permeated the meeting
# Original Title: start gates urges russian calm over expansion of nato end
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 41ms/step
# Predicted Title:  start russia says it will meet with russia end
#
#
# Abstract: if the candidate for chancellor angela merkel’s party loses the vote it will effectively serve as no confidence vote that could lead to new elections or party coup
# Original Title: start presidential vote tests merkel’s ailing coalition in germany end
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# Predicted Title:  start in britain election could be sworn in the parliament end
#
#
# Abstract: india’s prime minister narendra modi spoke to reporters in beijing on friday after meeting with premier li keqiang of china mr modi said progress had been made on some issues
# Original Title: start indian premier discusses talks in china end
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# Predicted Title:  start china and china meet with china end
#
#
# Abstract: highlights from the international herald tribune archives rebels gain ground in mexico in 1914 russia has its eyes on satellites in 1964
# Original Title: start in our pages april 1 end
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted Title:  start 1966 u s troops in russia end
#
#
# Abstract: turkey’s foreign minister speaks on new agreement with the united states to flush islamic state fighters out of northern syria
# Original Title: start turkey announces anti isis operation end
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted Title:  start u s envoy to send more to isis in syria end
#
#
# Abstract: mexico had insisted that most of the 30 000 people killed have some association with the illicit trade but they now concede that innocents are being caught up in the violence
# Original Title: start civilians falling victim to mexico drug war end
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start u s says it will have been killed in syria end
#
#
# Abstract: ciudad juárez became infamous for attacks beginning in the 1990s that left hundreds of women dead but as international attention moved on the killings have continued
# Original Title: start wave of violence swallows more women in juárez end
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start a family of the family of the victims of the end
#
#
# Abstract: seen less frequently accompanying the leader in his public activities it remained unclear whether vice marshal was removed from other key positions
# Original Title: in latest government shuffle north korean leader removes no official from top posts end
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start in south korea says he will be in south korea end
#
#
# Abstract: the proposed turing law named for the mathematician who was prosecuted in the 1950s provides for posthumous pardons and allows men who are still alive to apply for pardons
# Original Title: thousands of men to be pardoned for gay sex once crime in britain end
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start former rights chief is convicted of sexual abuse end
#
#
# Abstract: meeting the deadline was another in series of steps that iran promised to take as part of the nuclear agreement reached in july with six world powers
# Original Title: start iran meets atomic agency deadline for material on past activities end
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start iran nuclear talks with iran nuclear talks end
#
#
# Abstract: the pentagon said that “person of interest” in the 2012 attack in benghazi libya died in coordinated airstrikes in mosul iraq on june 15
# ...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start as coronavirus cases are still in the u s end
#
#
# Abstract: many schools attended by migrants have been destroyed recently but some parents and administrators view the as an exercise in population control
# Original Title: start china takes aim at rural influx end
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start in the world and the world’s of the world end
#
#
# Abstract: a compromise in the constituent assembly accepted that “the principles of islamic law” should guide law but leaves it up to parliament and the courts to determine how and what
# Original Title: start a role for religion in egyptian draft constitution end
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start egypt approves new government on the election end
#
#
# Abstract: tashi wangchuk who was detained after appearing in new york times video about tibetan language education faces 15 years in prison for inciting separatism
# Original Title: start china to try tibetan education advocate detained for years end
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start china sentences detained in china end
#
#
# Abstract: as washington bars americans from traveling to north korea humanitarian groups are uncertain whether they’ll be able to continue work in the isolated country
# Original Title: start u s deadline forces american aid workers to leave north korea end
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted Title:  start u s and russia agree to be in north korea end
#
#
# Abstract: a freight train was sitting idle after it had run over man on the tracks senior official was quoted as saying by the news media when commuter train smashed into its rear
# Original Title: start train crash in pakistan kills at least 4 end
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted Title:  start 2 missing in japan crash crash in south china end
#
#
# Abstract: not every nation agrees on what an impeachment means and not each case turns out badly for the defendant as several recent cases have demonstrated
# Original Title: start dilma rousseff was not impeached legal scholars say end
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted Title:  start trump says trump will be in the white house end
#
#
# Abstract: women working at brick kiln in amritsar punjab
# Original Title: start image of the day march 7 end
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# Predicted Title:  start image of the day june 14 end
#
#
# Abstract: while gold and copper mining have made mongolia the world’s fastest growing economy they have also created some health and environmental problems in boom towns throughout the gobi desert
# Original Title: start a changing landscape end
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# Predicted Title:  start in japan and the world’s of the arctic end
#
#
# Abstract: a reporter takes the same route from liberia to the united states as thomas eric duncan the man who after traveling on to dallas fell to the disease
# Original Title: start in travel out of liberia nothing is simply routine end
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# Predicted Title:  start a american burns in the shooting of the end
#
#
# Abstract: as part of summit agreement the south said it would be removing propaganda loudspeakers and the north decreed it would its clocks with the south
# Original Title: start south korea to end propaganda broadcasts along border with north end
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted Title:  start north korea says it will meet with north korea end
#
#
# Abstract: it was coincidence of scheduling for the german chancellor angela merkel but the difference in the receptions of the former and current presidents was telling
# Original Title: start trump and obama visited europe one got warm welcome end
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start in britain to the vatican end
#
#
# Abstract: american officials gave permission for president nicolás maduro to fly over puerto rico and denied that they had tried to bar mr maduro from united states airspace
# Original Title: start u s denies trying to bar venezuelan president from airspace end
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# Predicted Title:  start mexico to investigate u s is questioned in mexico end
#
#
# Abstract: a decades old quarrel over two islets has flared some say in response to greek court’s refusal to extradite eight turkish airmen
# Original Title: start turkey and greece trade jabs in island dispute end
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# Predicted Title:  start russian court says it will be detained in russia end
#
#
# Abstract: the times had experts answer questions about the high suicide rates among veterans
# Original Title: start questions and answers about veteran suicides end
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted Title:  start in afghanistan end
#
#
# Abstract: highlights from the international herald tribune archives thousands of volunteers join the finnish army
# Original Title: start 1940 thousands join finnish army end
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted Title:  start 1940 war in war end
#
#
# Abstract: the world health organization acknowledged it was not prepared to deal with the ebola outbreak and vowed to overhaul the way it handles epidemics
# Original Title: start w h o promises reform after criticism over ebola response end
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted Title:  start w h o chief is seen in south africa end
#
#
# Abstract: argentina’s president alberto fernández has made the rights of women and of gay and transgender people central to his government even through recession and pandemic
# Original Title: start argentina moves toward legal abortion amid push for women’s rights end
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted Title:  start in ireland and new zealand to seek more to the law end
